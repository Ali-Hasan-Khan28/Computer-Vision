# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Hasan-Khan28/Computer-Vision/blob/main/CVLab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
# Load an image
image = cv2.imread(r'/content/landscape.jpeg')
# Adjust brightness and contrast
alpha = 1.5 # Contrast control (1.0 is no change)
beta = -50 # Brightness control (0 is no change)
adjusted_image = cv2.convertScaleAbs (image, alpha=alpha, beta=beta)
# Display the original and adjusted images
cv2.imshow("Original Image", image)
cv2.imshow("Adjusted Image", adjusted_image)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-4-9f8a8f211ac7> in <cell line: 9>()
#       7 adjusted_image = cv2.convertScaleAbs (image, alpha=alpha, beta=beta)
#       8 # Display the original and adjusted images
# ----> 9 cv2.imshow("Original Image", image)
#      10 cv2.imshow("Adjusted Image", adjusted_image)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
# ...

# %%
from google.colab.patches import cv2_imshow
import cv2

# Load an image
image = cv2.imread(r'/content/landscape.jpeg')

# Adjust brightness and contrast
alpha = 1.5  # Contrast control (1.0 is no change)
beta = -50   # Brightness control (0 is no change)
adjusted_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# Display the original image
cv2_imshow(image)

# Display the adjusted image
cv2_imshow(adjusted_image)
# Out:
# <PIL.Image.Image image mode=RGB size=267x189>
# <PIL.Image.Image image mode=RGB size=267x189>

# %%
import requests
import numpy as np
import cv2
from PIL import Image
from io import BytesIO

# URL of the image you want to load
image_url = "https://parade.com/.image/ar_1:1%2Cc_fill%2Ccs_srgb%2Cfl_progressive%2Cq_auto:good%2Cw_1200/MTk3MzM3ODU4NTU2NTY4Nzc1/marveldisney.jpg"

# Fetch the image from the URL
response = requests.get(image_url)
image_bytes = BytesIO(response.content)

# Open the image using PIL
image_pil = Image.open(image_bytes)

# Convert the PIL image to a NumPy array
image_array = np.array(image_pil)

# Display the image array
print(image_array)
# Out:
# [[[ 23   0 124]
#   [ 31   5 132]
#   [ 42  15 144]
#   ...
#   [137 131 205]
#   [124 119 186]
#   [ 90  85 149]]
#
#  [[ 25   0 124]
#   [ 31   5 132]
#   [ 39  13 140]
#   ...
#   [137 131 205]
#   [124 119 186]
#   [ 90  85 149]]
#
#  [[ 29   3 126]
#   [ 30   4 127]
#   [ 33   7 132]
#   ...
#   [137 131 205]
#   [124 119 186]
#   [ 91  86 150]]
#
#  ...
#
#  [[ 94  62 205]
#   [ 90  58 201]
#   [ 88  56 199]
#   ...
#   [101  49 160]
#   [ 99  45 157]
#   [ 99  42 155]]
#
#  [[ 90  58 201]
#   [ 86  54 197]
#   [ 84  52 195]
#   ...
#   [101  49 160]
#   [ 99  45 157]
#   [ 98  41 154]]
#
#  [[ 88  56 199]
#   [ 84  52 195]
#   [ 81  49 192]
#   ...
#   [101  49 160]
#   [ 98  44 156]
#   [ 98  41 154]]]

# %%
cv2_imshow(image_array)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200>
